# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
full_data=pd.read_csv('/content/drive/MyDrive/ML_Training/diabetes.csv')

# %%
full_data.shape
# Out:
# (442, 11)

# %%
full_data.head(5)
# Out:
#    age  sex   bmi     bp   s1     s2    s3   s4      s5  s6    y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
full_data['sex'].value_counts()
# Out:
# 1    235
# 2    207
# Name: sex, dtype: int64

# %%
full_data.describe()
# Out:
#               age         sex         bmi          bp          s1          s2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                s3          s4          s5          s6           y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# min     22.000000    2.000000    3.258100   58.000000   25.000000
# 25%     40.250000    3.000000    4.276700   83.250000   87.000000
# 50%     48.000000    4.000000    4.620050   91.000000  140.500000
# 75%     57.750000    5.000000    4.997200   98.000000  211.500000
# max     99.000000    9.090000    6.107000  124.000000  346.000000

# %%
full_data.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex  0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi  0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp   0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1   0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2   0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3  -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4   0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5   0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6   0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# y    0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#            s4        s5        s6         y
# age  0.203841  0.270774  0.301731  0.187889
# sex  0.332115  0.149916  0.208133  0.043062
# bmi  0.413807  0.446157  0.388680  0.586450
# bp   0.257650  0.393480  0.390430  0.441482
# s1   0.542207  0.515503  0.325717  0.212022
# s2   0.659817  0.318357  0.290600  0.174054
# s3  -0.738493 -0.398577 -0.273697 -0.394789
# s4   1.000000  0.617859  0.417212  0.430453
# s5   0.617859  1.000000  0.464669  0.565883
# s6   0.417212  0.464669  1.000000  0.382483
# y    0.430453  0.565883  0.382483  1.000000

# %%
dataX=full_data.drop(columns=['y','sex'])
dataY=pd.DataFrame({'y':full_data.y})

# %%
from sklearn.model_selection import train_test_split

# %%
trainX, testX, trainY, testY = train_test_split(dataX, dataY, test_size=0.20, random_state=11)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(trainX,trainY)
# Out:
# LinearRegression()

# %%
# WHAT HAS MODEL LEARNED
# Hypothesis: theta0 + theta1 *area + theta2*bedrooms + theta3 * furnished
# theta0 = intercept
print ('Intercept:' , model.intercept_)
print ('coefficients:' , model.coef_)
# Out:
# Intercept: [-318.27739786]
# coefficients: [[-3.73237101e-01  5.98786253e+00  9.20818096e-01 -5.72969894e-01
#    3.24244488e-01  3.64688266e-02  1.28353064e-01  6.20168892e+01
#    2.70529077e-01]]

# %%
predictions = model.predict(testX)
type(predictions)
# Out:
# numpy.ndarray

# %%
result=pd.DataFrame({'prediction': predictions.flatten(), 'actual' : testY.y})
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
model.score(trainX,trainY)
# Out:
# 0.47224455798145215

# %%
model.score(testX,testY)
# Out:
# 0.5661960295492583

# %%
from sklearn.linear_model import SGDRegressor

model = SGDRegressor()
model.fit(trainX,trainY.values.ravel())
# Out:
# SGDRegressor()

# %%
from sklearn.linear_model import SGDRegressor

#model = SGDRegressor(verbose=1, max_iter=10,eta0=0.00000003, shuffle=False)
model = SGDRegressor(eta0=0.00005, shuffle=False, max_iter=10000)
model.fit(trainX,trainY.values.ravel())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1507: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# SGDRegressor(eta0=5e-05, max_iter=10000, shuffle=False)

# %%
print('intercept:',model.intercept_)
print ('coefficients:' , model.coef_)
print('Score:',model.score(trainX,trainY))
# Out:
# intercept: [-2.95593481]
# coefficients: [-0.33281275  5.72684931  0.86485082  1.72819821 -1.69684206 -3.14469667
#  -8.44901405 -0.93506311  0.01927303]
# Score: 0.4458349590819076

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
trainX = scaler.fit_transform(trainX)
trainX
# Out:
# array([[-0.11285445,  0.2019469 , -1.04256183, ...,  1.48019898,
#          0.33108472,  0.08826454],
#        [-0.26346928, -1.18496468, -0.00871303, ..., -0.83589251,
#         -0.35092728,  0.9489657 ],
#        [ 1.39329383, -0.8151216 , -0.52563743, ..., -0.83589251,
#         -0.56643293,  0.08826454],
#        ...,
#        [ 1.46860125,  0.27129248,  0.95128942, ..., -0.06386201,
#          0.5573169 , -0.08387569],
#        [-0.11285445, -0.88446717, -0.89486914, ..., -0.83589251,
#          0.23279074, -0.16994581],
#        [-1.09185084, -0.23724177,  1.24667479, ...,  1.48019898,
#          0.66789763, -0.08387569]])

# %%
testX = scaler.transform(testX)

# %%
from sklearn.linear_model import SGDRegressor

#model = SGDRegressor(verbose=1, max_iter=10,eta0=0.00000003, shuffle=False)
model = SGDRegressor(eta0=0.01, shuffle=False)
model.fit(trainX,trainY.values.ravel())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1507: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# SGDRegressor(shuffle=False)

# %%
print('intercept:',model.intercept_)
print ('coefficients:' , model.coef_)
print('Score:',model.score(trainX,trainY))
# Out:
# intercept: [151.45370884]
# coefficients: [ -4.91764439  25.99146354  12.40378171 -15.84370938   6.40754067
#   -1.34048899  -0.58952095  29.98920259   2.96962503]
# Score: 0.4720961810230766

# %%
import numpy as np
new_data = full_data.copy()

# %%
new_data.describe()
new_data.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex  0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi  0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp   0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1   0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2   0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3  -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4   0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5   0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6   0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# y    0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#            s4        s5        s6         y
# age  0.203841  0.270774  0.301731  0.187889
# sex  0.332115  0.149916  0.208133  0.043062
# bmi  0.413807  0.446157  0.388680  0.586450
# bp   0.257650  0.393480  0.390430  0.441482
# s1   0.542207  0.515503  0.325717  0.212022
# s2   0.659817  0.318357  0.290600  0.174054
# s3  -0.738493 -0.398577 -0.273697 -0.394789
# s4   1.000000  0.617859  0.417212  0.430453
# s5   0.617859  1.000000  0.464669  0.565883
# s6   0.417212  0.464669  1.000000  0.382483
# y    0.430453  0.565883  0.382483  1.000000

# %%
new_data['bmi_square'] = new_data['bmi']*new_data['bmi']

# %%
dataX=new_data.drop(columns=['y','sex'])
dataY = pd.DataFrame(new_data['y'])

trainX, testX, trainY, testY = train_test_split(dataX, dataY, test_size=0.20, random_state=11)

# %%
scaler = StandardScaler()
trainX.columns
collist=trainX.columns.tolist()
collist
# Out:
# ['age', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6', 'bmi_square']

# %%
trainX=scaler.fit_transform(trainX)
trainX = pd.DataFrame(trainX, columns=collist)

# %%
testX=scaler.transform(testX)
testX = pd.DataFrame(testX, columns=collist)

# %%
from sklearn.linear_model import SGDRegressor

#model = SGDRegressor(verbose=1, max_iter=10,eta0=0.00000003, shuffle=False)
model = SGDRegressor(eta0=0.001, shuffle=False)
model.fit(trainX,trainY)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1507: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# SGDRegressor(eta0=0.001, shuffle=False)

# %%
print('intercept:',model.intercept_)
print ('coefficients:' , model.coef_)
print('Score:',model.score(trainX,trainY))
# Out:
# intercept: [151.61787936]
# coefficients: [-4.57414678  9.41837581 12.41397797 -2.85648433 -4.07564699 -6.39589013
#  -0.89407526 25.58564555  3.04285443 16.77546521]
# Score: 0.4741436889847995

# %%
print('intercept:',model.intercept_)
print ('coefficients:' , model.coef_)
print('Score:',model.score(testX,testY))
# Out:
# intercept: [151.61787936]
# coefficients: [-4.57414678  9.41837581 12.41397797 -2.85648433 -4.07564699 -6.39589013
#  -0.89407526 25.58564555  3.04285443 16.77546521]
# Score: 0.5628384744206317

# %%
full_data_dp =full_data

# %%
full_data_dp=full_data_dp.drop(columns=['s1','s2','s3','s4','s5','s6'])

# %%
full_data_dp.head(5)
# Out:
#    age  sex   bmi     bp    y
# 0   59    2  32.1  101.0  151
# 1   48    1  21.6   87.0   75
# 2   72    2  30.5   93.0  141
# 3   24    1  25.3   84.0  206
# 4   50    1  23.0  101.0  135
